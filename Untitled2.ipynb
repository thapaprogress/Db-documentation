# %% [markdown]
# <a href="https://colab.research.google.com/github/thapaprogress/Db-documentation/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.regression.linear_model import yule_walker
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)

# %% [markdown]
# Simulate AR(2) Process

# %%
ar2 = np.array([1, 0.33, 0.5])
ma2 = np.array([1, 0, 0])

# %%
print(ar2)
# Out:
# [1.   0.33 0.5 ]

# %%
AR2_process = ArmaProcess(ar2, ma2).generate_sample(nsample=1000)

# %%
plt.plot(AR2_process)

# %%
plt.plot(AR2_process)
plt.title('simulated AR(2) Process')
plt.xlim(0, 200)
plt.show()

# %%
plot_acf(AR2_process);

# %%
plot_pacf(AR2_process);

# %%
rho, sigma = yule_walker(AR2_process, 2, method='mle')
print(f'rho: {-rho}')
print(f'sigma: {sigma}')
# Out:
# rho: [0.33520961 0.45830103]
# sigma: 1.0153460655520035

# %% [markdown]
# Simulate AR(3) Process

# %%
ar3 = np.array([1, 0.33, 0.5, 0.07])
ma3 = np.array([1, 0, 0, 0])

# %%
AR3_process = ArmaProcess(ar3, ma3).generate_sample(nsample=10000)

# %%
plt.plot(AR3_process)
plt.title('Simulated AR(3) Process')
plt.xlim(0, 200)
plt.show()

# %%
plot_acf(AR3_process);
plot_pacf(AR3_process);

# %%
rho, sigma = yule_walker(AR3_process, 3, method='mle')

print(f'rho: {-rho}')
print(f'sigma: {sigma}')
# Out:
# rho: [0.32361059 0.49584409 0.06304433]
# sigma: 0.9925529154339099
